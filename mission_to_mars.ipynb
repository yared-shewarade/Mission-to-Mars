# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
from splinter import Browser
import time
import re

# %% [markdown]
# ## NASA Mars News

# %%
# downloading data from NASA Mars News Site
page = requests.get("https://mars.nasa.gov/news/")

#checking for downloading successfuly
page
# Out:
# <Response [200]>

# %%
# Printing out the HTML content of the page using content property
page.content
# Out:
# b'<!DOCTYPE html>\n<html lang=\'en\' xml:lang=\'en\' xmlns=\'http://www.w3.org/1999/xhtml\'>\n<head>\n<meta content=\'text/html; charset=utf-8\' http-equiv=\'Content-Type\'>\n<!-- Always force latest IE rendering engine or request Chrome Frame -->\n<meta content=\'IE=edge,chrome=1\' http-equiv=\'X-UA-Compatible\'>\n<script type="text/javascript">window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"5e33925808","applicationID":"59562082","transactionName":"JVcPR0MLWApSRU1eAQVVEhxSC1oSUlkWbBMHXwRAHhdcCUA=","queueTime":0,"applicationTime":154,"agent":""}</script>\n<script type="text/javascript">(window.NREUM||(NREUM={})).loader_config={xpid:"VQcPUlZTDxAFXVRUBQEPVA=="};window.NREUM||(NREUM={}),__nr_require=function(t,n,e){function r(e){if(!n[e]){var o=n[e]={exports:{}};t[e][0].call(o.exports,function(n){var o=t[e][1][n];return r(o||n)},o,o.exports)}return n[e].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=
# ...

# %%
#Parasing a page with BeautifulSoup
soup = BeautifulSoup(page.text, "html.parser")

# %%
#formated HTML content nicely using the prettify method on the BeautifulSoup object
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <!-- Always force latest IE rendering engine or request Chrome Frame -->
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <script type="text/javascript">
#    window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"5e33925808","applicationID":"59562082","transactionName":"JVcPR0MLWApSRU1eAQVVEhxSC1oSUlkWbBMHXwRAHhdcCUA=","queueTime":0,"applicationTime":154,"agent":""}
#   </script>
#   <script type="text/javascript">
# ...

# %%
list(soup.children)
# Out:
# ['html',
#  '\n',
#  <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#  <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#  <!-- Always force latest IE rendering engine or request Chrome Frame -->
#  <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#  <script type="text/javascript">window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"5e33925808","applicationID":"59562082","transactionName":"JVcPR0MLWApSRU1eAQVVEhxSC1oSUlkWbBMHXwRAHhdcCUA=","queueTime":0,"applicationTime":154,"agent":""}</script>
# ...

# %%
#checking the type of each elements in the list
[type(item) for item in list(soup.children)]
# Out:
# [bs4.element.Doctype,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString]

# %% [markdown]
# As we can see from above type of elements, all of thems are BeautifulSoup objects.The first is a Doctype object, which contains information about the type of the document. The second and the last is NavigableString which represents text found in the HTML document. The third one, which contains other nested tags, is the most important that I am gonna diving in.

# %%
html = list(soup.children)[2]

# %%
html
# Out:
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <!-- Always force latest IE rendering engine or request Chrome Frame -->
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <script type="text/javascript">window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"5e33925808","applicationID":"59562082","transactionName":"JVcPR0MLWApSRU1eAQVVEhxSC1oSUlkWbBMHXwRAHhdcCUA=","queueTime":0,"applicationTime":154,"agent":""}</script>
# ...

# %%
news_title = html.find("title").get_text()

# %%
news_title
# Out:
# 'News  – NASA’s Mars Exploration Program '

# %%
paragraphs = soup.find_all("p")
for paragraph in paragraphs:
    new_p = paragraph.text

# %%
new_p
# Out:
# 'Managed by the Mars Exploration Program and the Jet Propulsion Laboratory for NASA’s Science Mission Directorate'

# %% [markdown]
# ## JPL Mars Space Images - Featured Image

# %%
executable_path = {'executable_path':'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
url_jpl = 'https://www.jpl.nasa.gov/spaceimages/?search=&category=Mars'
browser.visit(url_jpl)

# %%
browser.find_by_id("full_image").click()

# %%
html=browser.html
jpl_image = BeautifulSoup(html, "html.parser")

# %%
jpl_image
# Out:
# <!DOCTYPE html>
# ...

# %%
image_url = browser.visit

# %%
featured_image_url = browser.find_by_css(".fancybox-image").first["src"]

# %%
featured_image_url
# Out:
# 'https://www.jpl.nasa.gov/spaceimages/images/mediumsize/PIA19913_ip.jpg'

# %% [markdown]
# # Mars Weather

# %%
url_mars = "https://twitter.com/marswxreport?lang=en"
browser.visit(url_mars)
tweet_text = browser.find_by_css(".tweet-text")

# %%
for tweet in tweet_text:
    if tweet.text.partition(" ")[0]=="Sol":
        mars_weather = tweet.text
        break

# %%
mars_weather
# Out:
# 'Sol 2171 (2018-09-14), high -12C/10F, low -65C/-84F, pressure at 8.79 hPa, daylight 05:43-17:59'

# %% [markdown]
# # Mars Facts

# %%
url_mars_fact = "https://space-facts.com/mars/"
browser.visit(url_mars_fact)

# %%
tables = pd.read_html(url_mars_fact)
tables
# Out:
# [                      0                              1
#  0  Equatorial Diameter:                       6,792 km
#  1       Polar Diameter:                       6,752 km
#  2                 Mass:  6.42 x 10^23 kg (10.7% Earth)
#  3                Moons:            2 (Phobos & Deimos)
#  4       Orbit Distance:       227,943,824 km (1.52 AU)
#  5         Orbit Period:           687 days (1.9 years)
#  6  Surface Temperature:                  -153 to 20 °C
#  7         First Record:              2nd millennium BC
#  8          Recorded By:           Egyptian astronomers]

# %%
df = tables[0]

# %%
df.head
# Out:
# <bound method NDFrame.head of                       0                              1
# 0  Equatorial Diameter:                       6,792 km
# 1       Polar Diameter:                       6,752 km
# 2                 Mass:  6.42 x 10^23 kg (10.7% Earth)
# 3                Moons:            2 (Phobos & Deimos)
# 4       Orbit Distance:       227,943,824 km (1.52 AU)
# 5         Orbit Period:           687 days (1.9 years)
# 6  Surface Temperature:                  -153 to 20 °C
# 7         First Record:              2nd millennium BC
# 8          Recorded By:           Egyptian astronomers>

# %%
mars_df=df.set_index(0).rename(columns={1:"Value"})

# %%
mars_df.index.names = ["Planet Profile"]

# %%
mars_df
# Out:
#                                               Value
# Planet Profile
# Equatorial Diameter:                       6,792 km
# Polar Diameter:                            6,752 km
# Mass:                 6.42 x 10^23 kg (10.7% Earth)
# Moons:                          2 (Phobos & Deimos)
# Orbit Distance:            227,943,824 km (1.52 AU)
# Orbit Period:                  687 days (1.9 years)
# Surface Temperature:                  -153 to 20 °C
# First Record:                     2nd millennium BC
# Recorded By:                   Egyptian astronomers

# %%
mars_facts = mars_df.to_html()

# %%
# strip unwanted newlines to clean up the table.
mars_facts.replace('\n', '')
# Out:
# '<table border="1" class="dataframe">  <thead>    <tr style="text-align: right;">      <th></th>      <th>Value</th>    </tr>    <tr>      <th>Planet Profile</th>      <th></th>    </tr>  </thead>  <tbody>    <tr>      <th>Equatorial Diameter:</th>      <td>6,792 km</td>    </tr>    <tr>      <th>Polar Diameter:</th>      <td>6,752 km</td>    </tr>    <tr>      <th>Mass:</th>      <td>6.42 x 10^23 kg (10.7% Earth)</td>    </tr>    <tr>      <th>Moons:</th>      <td>2 (Phobos &amp; Deimos)</td>    </tr>    <tr>      <th>Orbit Distance:</th>      <td>227,943,824 km (1.52 AU)</td>    </tr>    <tr>      <th>Orbit Period:</th>      <td>687 days (1.9 years)</td>    </tr>    <tr>      <th>Surface Temperature:</th>      <td>-153 to 20 °C</td>    </tr>    <tr>      <th>First Record:</th>      <td>2nd millennium BC</td>    </tr>    <tr>      <th>Recorded By:</th>      <td>Egyptian astronomers</td>    </tr>  </tbody></table>'

# %%
# with print function to make readable easily
print(mars_facts)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Value</th>
#     </tr>
#     <tr>
#       <th>Planet Profile</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Equatorial Diameter:</th>
#       <td>6,792 km</td>
#     </tr>
#     <tr>
#       <th>Polar Diameter:</th>
#       <td>6,752 km</td>
#     </tr>
#     <tr>
#       <th>Mass:</th>
#       <td>6.42 x 10^23 kg (10.7% Earth)</td>
#     </tr>
#     <tr>
#       <th>Moons:</th>
#       <td>2 (Phobos &amp; Deimos)</td>
#     </tr>
#     <tr>
#       <th>Orbit Distance:</th>
#       <td>227,943,824 km (1.52 AU)</td>
#     </tr>
#     <tr>
#       <th>Orbit Period:</th>
#       <td>687 days (1.9 years)</td>
#     </tr>
#     <tr>
#       <th>Surface Temperature:</th>
#       <td>-153 to 20 °C</td>
#     </tr>
#     <tr>
#       <th>First Record:</th>
#       <td>2nd millennium BC</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# # Mars Hemispheres

# %% [markdown]
# From USGS Astrogeology site, there are four hemispheres and I am going to extract high resolution images for each of Mar's hemispheres
# 1. Cerberus Hemisphere Enhanced
# 2. Schiaparelli Hemisphere Enhanced
# 3. Syrtis Major Hemisphere Enhanced
# 4. Valles Marineris Hemisphere Enhanced

# %%
url_mars_hemi = "https://astrogeology.usgs.gov/search/results?q=hemisphere+enhanced&k1=target&v1=Mars"
browser.visit(url_mars_hemi)

# %%
Cerberus = browser.find_by_tag("h3")[0].text
Schiaparelli = browser.find_by_tag("h3")[1].text
Syrtis = browser.find_by_tag("h3")[2].text
Valles = browser.find_by_tag("h3")[3].text

# %%
browser.find_by_css(".thumb")[0].click()
Cerberus_img = browser.find_by_text("Sample")["href"]
browser.back()
browser.find_by_css(".thumb")[1].click()
Schiaparelli_img = browser.find_by_text("Sample")["href"]
browser.back()
browser.find_by_css(".thumb")[2].click()
Syrtis_img = browser.find_by_text("Sample")["href"]
browser.back()
browser.find_by_css(".thumb")[3].click()
Valles_img = browser.find_by_text("Sample")["href"]
browser.back()

# %%
hemisphere_image_urls = [
    {'title': Cerberus, 'img_url': Cerberus_img},
    {'title': Schiaparelli, 'img_url': Schiaparelli_img},
    {'title': Syrtis, 'img_url': Syrtis_img},
    {'title': Valles, 'img_url': Valles_img}
]

# %%
hemisphere_image_urls
# Out:
# [{'title': 'Cerberus Hemisphere Enhanced',
#   'img_url': 'http://astropedia.astrogeology.usgs.gov/download/Mars/Viking/cerberus_enhanced.tif/full.jpg'},
#  {'title': 'Schiaparelli Hemisphere Enhanced',
#   'img_url': 'http://astropedia.astrogeology.usgs.gov/download/Mars/Viking/schiaparelli_enhanced.tif/full.jpg'},
#  {'title': 'Syrtis Major Hemisphere Enhanced',
#   'img_url': 'http://astropedia.astrogeology.usgs.gov/download/Mars/Viking/syrtis_major_enhanced.tif/full.jpg'},
#  {'title': 'Valles Marineris Hemisphere Enhanced',
#   'img_url': 'http://astropedia.astrogeology.usgs.gov/download/Mars/Viking/valles_marineris_enhanced.tif/full.jpg'}]
